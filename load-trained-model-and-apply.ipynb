# %%
# Matplotlib config
# %matplotlib inline
# %config InlineBackend.figure_formats = ['svg']
# %config InlineBackend.rc = {'figure.figsize': (5.0, 3.0)}

import numpy as np
import pandas as pd
import seaborn as sns

import gzip
import numpy as np

# Tensorflow laden
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
model = keras.models.load_model("my-model.tf.keras")

# %%
import imageio.v3 as iio

img = iio.imread("9.png")[:, :, 0]

img = (255 - img).astype(np.float32) / 255

import matplotlib.pyplot as plt

plt.imshow(img)
plt.show()

# %%
#print(img.reshape(1, 28, 28, 1))

# %%
pred = model.predict(img.reshape(1, 28, 28, 1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %%
print(pred)
print("=> the recognised number =", np.argmax(pred, axis = 1))
# Out:
# [[3.4047483e-13 1.0289626e-11 2.6258192e-04 2.2566558e-01 2.2772845e-13
#   1.1857296e-04 4.9192721e-19 4.0651596e-10 3.5918033e-01 4.1477293e-01]]
# => the recognised number = [9]
